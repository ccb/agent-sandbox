# %% [markdown]
# # Dangertown Beatdown
#
# It's 1987 in Santa Morena. Detective Jack Slade wakes to a threatening phone
# message: crime boss "Boss D" has kidnapped his partner, Jetta Chang, and wants
# the audiotape that proves the mayor is on the take. You play Slade across the
# neon-soaked city -- refusing a bribe, working contacts at a strip club and a gang
# arcade, lifting the tape from the police evidence locker -- until a warehouse
# ambush gets Slade shot. The story then **switches protagonists**: you become
# rookie detective Jetta Chang, save Slade, gear up, and take down Boss D in his
# penthouse. Source: Parsely "Dangertown Beatdown" (pages 85-115).
#
# ---
#
# This notebook drives the game through its winning walkthrough so you can read the story unfold turn-by-turn, then lets you take the controls. The game logic lives in `test_gen/dangertown_beatdown/dangertown_beatdown.py`; here we just *play* it.

# %% [markdown]
# ## 1. Load the game
#
# We add the repo root to the path (so `text_adventure_games` imports) and load the game module by file path — the same trick the test suite uses, so it works no matter where Jupyter was started from.

# %%
import sys
import importlib.util
from pathlib import Path

# Walk up from the working directory to the repo root (the folder
# that contains `text_adventure_games/`).
root = Path.cwd().resolve()
while not (root / "text_adventure_games").is_dir() and root != root.parent:
    root = root.parent
sys.path.insert(0, str(root))

game_file = root / "test_gen/dangertown_beatdown/dangertown_beatdown.py"
spec = importlib.util.spec_from_file_location("dangertown_beatdown_nb", game_file)
mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)
print("loaded", game_file.name)
# Out:
# loaded dangertown_beatdown.py

# %% [markdown]
# ## 2. Build the world and look around
#
# `build_game()` assembles every room, item, and character and wires up the custom actions. `look` describes where you start.

# %%
game = mod.build_game()
game.parser.parse_command("look")
print(f"\nScore: {game.score}/{game.max_score}")
# Out:
# BEDROOM
# You're roused from sleep by neon light. It's 11:58 p.m. There's a closet and a
# mirror here. Your answering machine is flashing. A door leads out.
# Exits:
#  * Out to Apartment
#
# You see:
#  * mirror - a mirror
#         examine mirror
#  * window - the window
#         examine window
#  * sign - the neon sign
#         examine sign
#  * answering machine - the answering machine
#         play message
#  * closet - a closet
#         open closet
#
#
#
# Score: 0/100

# %% [markdown]
# ## 3. Play the winning walkthrough
#
# The walkthrough is the list of commands that solves the game. We build a fresh world and feed it the commands one at a time, printing each command (`>>>`) above the game's response so you can follow the solution.

# %%
game = mod.build_game()
game.parser.parse_command("look")

for cmd in mod.WALKTHROUGH:
    print(f"\n>>> {cmd}")
    game.do_command(cmd)
    if game.is_game_over():
        break

print("\n" + "=" * 60)
print(f"WON: {game.is_won()}   GAME OVER: {game.is_game_over()}")
print(f"SCORE: {game.score}/{game.max_score}")
# Out:
# BEDROOM
# You're roused from sleep by neon light. It's 11:58 p.m. There's a closet and a
# mirror here. Your answering machine is flashing. A door leads out.
# Exits:
#  * Out to Apartment
#
# You see:
#  * mirror - a mirror
#         examine mirror
#  * window - the window
#         examine window
#  * sign - the neon sign
#         examine sign
#  * answering machine - the answering machine
#         play message
#  * closet - a closet
#         open closet
#
#
#
# >>> play message
# A voice says, "Slade, you're gonna pay for shutting down our operation. We have
# your partner. Bring us the tape. Come alone."
#
# >>> open closet
# Jack slade opens the closet. In it you see: a police dress uniform, a leather
# jacket.
#
# >>> get jacket
# Jack Slade got the jacket.
#
# >>> wear jacket
# You put on the leather jacket. Your keys jingle in the pocket.
#
# >>> out
# Jack Slade moved to Apartment
# APARTMENT
# Home sweet home. A kettle and some instant coffee are on the counter by the
# stove. There's a newspaper on the table. Your bedroom is here, and a door leads
# out to Southside.
# Exits:
#  * Enter bedroom to Bedroom
#  * Out to Southside
#
# You see:
#  * kettle - a kettle
#         make coffee
#  * newspaper - a newspaper
#         read newspaper
#  * door - the front door
#         examine door
#  * peephole - the peephole
#         examine peephole
#  * envelope - an envelope of cash
#         examine envelope
#
#
#
# >>> make coffee
# You perform the sacred ritual: fill the kettle, set it on the stove and wait.
#
# >>> read newspaper
# Violent crime is up eight percent in Santa Morena. The mayor is pushing another
# waterfront deal, and some masked weirdo is beating up muggers.
# Someone knocks. "Slade. Open up." He kicks in the door and enters, blocking the
# exit -- a large man in a suit with a baseball bat. (TALK TO MAN.)
#
# >>> say no
# "Figured you might turn us down." He shoulders the baseball bat: "Since the
# carrot ain't working, let's try the stick." The kettle starts whistling... (HIT
# MAN WITH KETTLE.)
#
# >>> hit man with kettle
# You grab the hot kettle and smash it into the gangster's skull. He collapses,
# dropping the baseball bat.
#
# >>> get bat
# Jack Slade got the bat.
#
# >>> search man
# You search his pockets: an empty matchbook and a wallet fall to the floor. (GET
# MATCHBOOK, GET WALLET.)
#
# >>> get matchbook
# Jack Slade got the matchbook.
#
# >>> get wallet
# Jack Slade got the wallet.
#
# >>> out
# Jack Slade moved to Southside
# SOUTHSIDE
# You're outside a rundown apartment building in the Gaslight District. There's a
# strip club here. Your motorcycle is parked at the curb. Gaslight's North End is
# a short walk away; the open road is a ride away.
# Exits:
#  * Enter apartment to Apartment
#  * Enter strip club to Strip Club
#  * North to North End
#  * To downtown to Downtown
#  * To little italy to Little Italy
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> enter strip club
# Jack Slade moved to Strip Club
# STRIP CLUB
# Tiger'z Den is a seedy strip joint with animal-print decor. Some dancers sway
# onstage. You don't see anyone here to wait on you.
# Exits:
#  * Out to Southside
#
# You see:
#  * dancers - the dancers
#         tip dancers
#
#
#
# >>> tip dancers
# A dancer slips the $100 bill into her G-string. Like magic, the club's lone
# waitress appears -- it's your ex, Cat Marco.
#
# >>> give matchbook to cat
# Cat writes an address on the matchbook: "Pacific Towers, Morena Beach." "He
# hired some girls for a party -- bankers, lawyers, politicians."
#
# >>> out
# Jack Slade moved to Southside
# SOUTHSIDE
# You're outside a rundown apartment building in the Gaslight District. There's a
# strip club here. Your motorcycle is parked at the curb. Gaslight's North End is
# a short walk away; the open road is a ride away.
# Exits:
#  * Enter apartment to Apartment
#  * Enter strip club to Strip Club
#  * North to North End
#  * To downtown to Downtown
#  * To little italy to Little Italy
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> north
# Jack Slade moved to North End
# NORTH END
# Gaslight's North End. Some gang members loiter outside an arcade. A pay phone is
# on the corner. Southside is a short walk south.
# Exits:
#  * South to Southside
#  * Enter arcade to Arcade
#
# You see:
#  * pay phone - a pay phone
#         use phone
#         get quarter
#  * quarter - a quarter
#         put quarter on machine
#         get quarter
#
#
#
# >>> get quarter
# Jack Slade got the quarter.
#
# >>> enter arcade
# Jack Slade moved to Arcade
# ARCADE
# Dream Warriors is an arcade full of young toughs in gang colors. You recognize
# Cutter and his Southside Blades; a friendlier face is Trina "Rabbit" Rodriguez.
# Exits:
#  * Out to North End
#
# You see:
#  * games - rows of coin-op video games
#         put quarter on machine
# Characters:
#  * cutter - Cutter, of the Southside Blades
#  * rabbit - Trina "Rabbit" Rodriguez, of Los Dragóns
#
#
# >>> put quarter on machine
# Rabbit starts a two-player game and leans in close. "Boss D has your partner
# holed up at the Harbor View docks, loading bay #23. You didn't hear it from me."
# She wipes the floor with you. "Better luck next time."
#
# >>> out
# As you turn to leave, Cutter gets in your face. "Snitches get stitches." He
# flicks open his switchblade and slashes your cheek, drawing blood. He's fast,
# but he's left himself open. (HIT CUTTER WITH BAT.)
#
# >>> hit cutter with bat
# You hear his collarbone snap and he goes down, dropping his switchblade. Rabbit
# whispers, "This isn't your fight. Go find Gheorghe. He'll fix you up."
#
# >>> take switchblade
# Jack Slade got the switchblade.
#
# >>> out
# Jack Slade moved to North End
# NORTH END
# Gaslight's North End. Some gang members loiter outside an arcade. A pay phone is
# on the corner. Southside is a short walk south.
# Exits:
#  * South to Southside
#  * Enter arcade to Arcade
#
# You see:
#  * pay phone - a pay phone
#         use phone
#         get quarter
#
#
#
# >>> south
# Jack Slade moved to Southside
# SOUTHSIDE
# You're outside a rundown apartment building in the Gaslight District. There's a
# strip club here. Your motorcycle is parked at the curb. Gaslight's North End is
# a short walk away; the open road is a ride away.
# Exits:
#  * Enter apartment to Apartment
#  * Enter strip club to Strip Club
#  * North to North End
#  * To downtown to Downtown
#  * To little italy to Little Italy
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> get on motorcycle
# You climb onto your bike and start it up. Baby purrs.
#
# >>> drive to little italy
# Jack Slade moved to Little Italy
# LITTLE ITALY
# A charming neighborhood where the Old World meets the new. The 24-hour Pixel
# City Café is open; across the street is Gheorghe's boxing gym.
# Exits:
#  * Enter cafe to Pixel City Cafe
#  * Enter gym to Gheorghe's Gym
#  * To gaslight to Southside
#  * To downtown to Downtown
#  * To harbor view to Harbor View
#  * To morena beach to Morena Beach
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> park bike
# You park your ride and hit the streets on foot.
#
# >>> enter gym
# Jack Slade moved to Gheorghe's Gym
# GHEORGHE'S GYM
# You're inside the boxing gym. Gheorghe, who coached the Romanian Olympic team in
# '84, is here.
# Exits:
#  * Out to Little Italy
#
#
# Characters:
#  * gheorghe - Gheorghe, the old boxing coach
#
#
# >>> ask gheorghe for help
# Gheorghe gets out a first aid kit, cleans the wound and stitches it closed.
# "This will leave scar, but the way you look, it will be improvement, no?"
#
# >>> out
# Jack Slade moved to Little Italy
# LITTLE ITALY
# A charming neighborhood where the Old World meets the new. The 24-hour Pixel
# City Café is open; across the street is Gheorghe's boxing gym.
# Exits:
#  * Enter cafe to Pixel City Cafe
#  * Enter gym to Gheorghe's Gym
#  * To gaslight to Southside
#  * To downtown to Downtown
#  * To harbor view to Harbor View
#  * To morena beach to Morena Beach
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> enter cafe
# Jack Slade moved to Pixel City Cafe
# PIXEL CITY CAFE
# A 24-hour coffee shop with a lunch counter and a well-lit pastry case. Marge is
# here. "What'll it be, hon? The usual?"
# Exits:
#  * Out to Little Italy
#
# You see:
#  * case - the pastry case
#         get donuts
#  * donuts - a box of day-old donuts
#         get donuts
#         give o'brien donuts
# Characters:
#  * marge - Marge, the café owner
#
#
# >>> order the usual
# You sit at the counter and Marge pours you a fresh cup of hot coffee.
#
# >>> drink coffee
# You feel better -- almost like you could single-handedly take on the Mob, rescue
# your partner and clean up organized crime in Santa Morena.
#
# >>> get donuts
# Jack Slade got the donuts.
#
# >>> out
# Jack Slade moved to Little Italy
# LITTLE ITALY
# A charming neighborhood where the Old World meets the new. The 24-hour Pixel
# City Café is open; across the street is Gheorghe's boxing gym.
# Exits:
#  * Enter cafe to Pixel City Cafe
#  * Enter gym to Gheorghe's Gym
#  * To gaslight to Southside
#  * To downtown to Downtown
#  * To harbor view to Harbor View
#  * To morena beach to Morena Beach
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> get on motorcycle
# You climb onto your bike and start it up. Baby purrs.
#
# >>> drive to downtown
# Jack Slade moved to Downtown
# DOWNTOWN
# Downtown: a few struggling tech startups and Santa Morena's police department.
# Graffiti reads DANGERTOWN over the old city slogan.
# Exits:
#  * Enter police station to Police Station
#  * To little italy to Little Italy
#  * To harbor view to Harbor View
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> park bike
# You park your ride and hit the streets on foot.
#
# >>> enter police station
# Jack Slade moved to Police Station
# POLICE STATION
# Sergeant O'Brien is at his desk going over paperwork. You see the police chief's
# office and the hallway leading to the evidence locker.
# Exits:
#  * Out to Downtown
#  * Enter evidence locker to Evidence Locker
#  * Enter chief's office to Chief's Office
#
#
# Characters:
#  * o'brien - Sergeant O'Brien
#
#
# >>> give o'brien donuts
# "Slade, you're all right. I'll go grab us some coffee. Sit tight." He stands and
# exits, leaving behind his keys and the case file.
#
# >>> get key ring
# Jack Slade got the key ring.
#
# >>> enter evidence locker
# Jack Slade moved to Evidence Locker
# EVIDENCE LOCKER
# A storage area crammed with cardboard boxes, each assigned a case number.
# Exits:
#  * Out to Police Station
#
#
#
#
#
# >>> find box
# You find box #198X: documents, surveillance photos and a spool of reel-to-reel
# audiotape. (TAKE AUDIOTAPE.)
#
# >>> take audiotape
# You hear footsteps approaching down the hall... better return the keys.
#
# >>> out
# Jack Slade moved to Police Station
# POLICE STATION
# Sergeant O'Brien is at his desk going over paperwork. You see the police chief's
# office and the hallway leading to the evidence locker.
# Exits:
#  * Out to Downtown
#  * Enter evidence locker to Evidence Locker
#  * Enter chief's office to Chief's Office
#
# You see:
#  * case file - a case file
#
#
#
# >>> return keys
# You set O'Brien's key ring back on the sergeant's desk. No harm, no foul.
#
# >>> out
# Jack Slade moved to Downtown
# DOWNTOWN
# Downtown: a few struggling tech startups and Santa Morena's police department.
# Graffiti reads DANGERTOWN over the old city slogan.
# Exits:
#  * Enter police station to Police Station
#  * To little italy to Little Italy
#  * To harbor view to Harbor View
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> get on motorcycle
# You climb onto your bike and start it up. Baby purrs.
#
# >>> drive to harbor view
# Jack Slade moved to Harbor View
# HARBOR VIEW
# A rundown industrial area on the water's edge. Numbered loading bays stretch
# into the dark. Some flashy sports cars are parked here.
# Exits:
#  * Enter bay #23 to Warehouse
#  * To morena beach to Morena Beach
#  * To little italy to Little Italy
#  * To downtown to Downtown
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#
#
#
# >>> park bike
# You park your ride and hit the streets on foot.
#
# >>> find bay
# Bay #23 -- yeah, you see it. Just a few doors down from the cars. (ENTER BAY
# #23.)
#
# >>> enter bay #23
# Jack Slade moved to Warehouse
# WAREHOUSE
# A maze of crates and shipping containers, dark save for a single floodlight
# illuminating a lone woman tied to a chair.
# Exits:
#  * Out to Harbor View
#
# You see:
#  * woman - a woman tied to a chair
#         free jetta chang
# Characters:
#  * Jetta Chang - rookie detective Jetta Chang
#
#
# >>> free jetta chang
# You cut through her restraints. Rocco emerges from the shadows, flanked by armed
# goons. "Slade. Give us the tape and we let you walk out of here." (GIVE TAPE.)
#
# >>> give tape
# You hand over the tape. Rocco starts to walk away, then stops. "I lied. Kill 'em
# both."
# Whether you run, fight or negotiate, the big goon shoots Slade in the stomach.
# You watch with horror as Jack drops to the floor.
#
# You are now rookie detective JETTA CHANG. A masked girl -- Knockout -- drops
# from a shipping container and decks a goon, but another raises his SMG to waste
# you both. (ATTACK GOON.)
#
# >>> attack goon
# You spin-kick the goon with the Fu Manchu mustache. He goes down like a sack of
# bricks. Knockout nods at you.
#
# >>> search goon
# You find a half-eaten candy bar and keys to a Porsche. (GET PORSCHE KEYS.)
#
# >>> get porsche keys
# Jetta Chang got the porsche keys.
#
# >>> drag slade out
# You drag Slade out from Bay #23 into the parking lot. There you find his
# precious Kawasaki and a white Porsche 911. (USE KEY ON PORSCHE.)
#
# >>> use key on porsche
# You unlock the car and manage to get Slade into the passenger seat. There's a
# car phone here. (CALL 911, then DRIVE TO DOWNTOWN.)
#
# >>> call 911
# The dispatcher puts you through to the desk sergeant. "Get back downtown as soon
# as you can. We'll have an ambulance ready and waiting." (DRIVE TO DOWNTOWN.)
#
# >>> drive to downtown
# Jetta Chang moved to Downtown
# DOWNTOWN
# Downtown: a few struggling tech startups and Santa Morena's police department.
# Graffiti reads DANGERTOWN over the old city slogan.
# Exits:
#  * Enter police station to Police Station
#  * To little italy to Little Italy
#  * To harbor view to Harbor View
#
# You see:
#  * porsche - a white Porsche 911
#         use key on porsche
#
#
# An ambulance is waiting. The paramedics load Slade inside and rush him to the
# hospital. You may have just saved his life.
#
# >>> get out
# You park your ride and hit the streets on foot.
#
# >>> enter police station
# Jetta Chang moved to Police Station
# POLICE STATION
# Sergeant O'Brien is at his desk going over paperwork. You see the police chief's
# office and the hallway leading to the evidence locker.
# Exits:
#  * Out to Downtown
#  * Enter evidence locker to Evidence Locker
#  * Enter chief's office to Chief's Office
#
# You see:
#  * case file - a case file
#
#
#
# >>> enter chief's office
# Jetta Chang moved to Chief's Office
# CHIEF'S OFFICE
# The police chief is here at his desk.
# Exits:
#  * Out to Police Station
#
# You see:
#  * badge - a Santa Morena detective's badge
#         get badge
#         show badge
#  * gun - a loaded Beretta 92S
#         get gun
# Characters:
#  * chief - the police chief
#
#
# >>> get badge
# Jetta Chang got the badge.
#
# >>> get gun
# Jetta Chang got the gun.
# "Detective Chang, consider yourself back on the case. Now do what you gotta do!"
#
# >>> out
# Jetta Chang moved to Police Station
# POLICE STATION
# Sergeant O'Brien is at his desk going over paperwork. You see the police chief's
# office and the hallway leading to the evidence locker.
# Exits:
#  * Out to Downtown
#  * Enter evidence locker to Evidence Locker
#  * Enter chief's office to Chief's Office
#
# You see:
#  * case file - a case file
#
#
#
# >>> out
# Jetta Chang moved to Downtown
# DOWNTOWN
# Downtown: a few struggling tech startups and Santa Morena's police department.
# Graffiti reads DANGERTOWN over the old city slogan.
# Exits:
#  * Enter police station to Police Station
#  * To little italy to Little Italy
#  * To harbor view to Harbor View
#
# You see:
#  * porsche - a white Porsche 911
#         use key on porsche
#
#
#
# >>> enter porsche
# You drop into the driver's seat of the Porsche.
#
# >>> drive to harbor view
# Jetta Chang moved to Harbor View
# HARBOR VIEW
# A rundown industrial area on the water's edge. Numbered loading bays stretch
# into the dark. Some flashy sports cars are parked here.
# Exits:
#  * Enter bay #23 to Warehouse
#  * To morena beach to Morena Beach
#  * To little italy to Little Italy
#  * To downtown to Downtown
#
# You see:
#  * motorcycle - a black Kawasaki GPZ900R
#         get on motorcycle
#  * porsche - a white Porsche 911
#         use key on porsche
#
#
#
# >>> drive to morena beach
# Jetta Chang moved to Morena Beach
# MORENA BEACH
# Where the money lives: gated communities, seaside mansions and luxury high-
# rises. Pacific Towers is one of Santa Morena's tallest buildings.
# Exits:
#  * Enter pacific towers to Pacific Towers
#  * To little italy to Little Italy
#  * To harbor view to Harbor View
#
# You see:
#  * porsche - a white Porsche 911
#         use key on porsche
#
#
#
# >>> get out
# You park your ride and hit the streets on foot.
#
# >>> show badge
# The guards let you pass. The man at the front desk picks up a phone and makes a
# call.
#
# >>> enter pacific towers
# Jetta Chang moved to Pacific Towers
# PACIFIC TOWERS
# An imposing tower of concrete, glass and steel. Guards are posted in the lobby.
# There's an elevator here.
# Exits:
#  * Out to Morena Beach
#  * Enter elevator to Elevator
#
#
#
#
#
# >>> enter elevator
# Jetta Chang moved to Elevator
# ELEVATOR
# You're in an elevator. There's a control panel here.
# Exits:
#  * Out to Pacific Towers
#
# You see:
#  * control panel - the elevator control panel
#         push p
#         scan rocco's thumb
#
#
# The doors open on a very surprised Rocco Falcone. He mutters a colorful
# expression and reaches inside his jacket. (SHOOT ROCCO or PUNCH ROCCO -- fast!)
#
# >>> punch rocco
# You make short work of the gangster. He'll live. The doors close behind you.
#
# >>> scan rocco's thumb
# You place Rocco's thumb on the scanner. The button marked P lights up. (PUSH P.)
#
# >>> push p
# The elevator ascends. Eventually you reach the penthouse:
#
# A spacious apartment all done up in chrome and white. Boss D is here, enjoying a
# glass of wine with the mayor of Santa Morena. The mayor nervously clutches a
# leather attaché case.
#
# >>> search boss d
# You find a pearl-handled S&W .38 Special and the stolen audiotape, which links
# him to your kidnapping. More than enough to put him away. (ARREST BOSS D.)
#
# >>> arrest boss d
# You knock Boss D to his knees and read him his rights. A SWAT team barges in:
# "EVERYONE GET DOWN ON THE GROUND!" Boss D turns witness, pleads down to 20 years
# and sends the mayor to jail. Slade recovers and gets the Purple Heart; you get
# the Meritorious Service Award and a promotion to lieutenant. Best of all, you
# get to see Jack in his dress uniform at the medal ceremony. You never let him
# live it down. THE END.  (Score: 100/100)
#
# ============================================================
# WON: True   GAME OVER: True
# SCORE: 100/100

# %% [markdown]
# ## 4. Take the controls
#
# Start a fresh game and drive it yourself. Call `do("...")` with any command — `look`, `go north`, `get lamp`, `inventory`, `examine door`, and so on. Re-run the build cell to start over.
#
# (For a classic blocking prompt-loop instead, call `game.game_loop()`.)

# %%
game = mod.build_game()

def do(command):
    """Run one command against the live game."""
    game.do_command(command)

do("look")
# Out:
# BEDROOM
# You're roused from sleep by neon light. It's 11:58 p.m. There's a closet and a
# mirror here. Your answering machine is flashing. A door leads out.
# Exits:
#  * Out to Apartment
#
# You see:
#  * mirror - a mirror
#         examine mirror
#  * window - the window
#         examine window
#  * sign - the neon sign
#         examine sign
#  * answering machine - the answering machine
#         play message
#  * closet - a closet
#         open closet

# %%
do("inventory")
# Out:
# Jack Slade's inventory is empty.
